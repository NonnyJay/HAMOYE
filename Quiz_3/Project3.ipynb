# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00471/Data_for_UCI_named.csv'
df_e = pd.read_csv(url,error_bad_lines=False)
df_e
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
# ...

# %%
df_e['stabf'].value_counts()
# Out:
# unstable    6380
# stable      3620
# Name: stabf, dtype: int64

# %%
# Checking for null rows and values
df_e.isna().sum()
# Out:
# tau1     0
# tau2     0
# tau3     0
# tau4     0
# p1       0
# p2       0
# p3       0
# p4       0
# g1       0
# g2       0
# g3       0
# g4       0
# stab     0
# stabf    0
# dtype: int64

# %%
df_e = df_e.drop(columns=['stab'])
df_e
# Out:
#           tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0     2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1     9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2     8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3     0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4     3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  2.930406  9.487627  2.376523  6.187797  3.343416 -0.658054 -1.449106
# 9996  3.392299  1.274827  2.954947  6.894759  4.349512 -1.663661 -0.952437
# 9997  2.364034  2.842030  8.776391  1.008906  4.299976 -1.380719 -0.943884
# 9998  9.631511  3.994398  2.757071  7.821347  2.514755 -0.966330 -0.649915
# 9999  6.530527  6.781790  4.349695  8.673138  3.492807 -1.390285 -1.532193
#
#             p4        g1        g2        g3        g4     stabf
# ...

# %%
X = df_e.drop(columns='stabf')
y = df_e['stabf']

# %%
#split the data into training and testing sets

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
# Feature Scaling of test and train data
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train = sc.fit_transform(x_train)
#y_train = sc.fit_transform(y_train)
x_test = sc.transform(x_test)

# %%
## Random forest Classifier training

from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=20, random_state=0)
rfc.fit(x_train, y_train)
rfc_pred = rfc.predict(x_test)

# %%
## Extra Tree Classifier Traing

from sklearn.ensemble import ExtraTreesClassifier
#extra_trees = ExtraTreesClassifier(n_estimators=100, random_state=0)
extra_trees = ExtraTreesClassifier(random_state=1)
extra_trees.fit(x_train, y_train)

extra_trees_pred = extra_trees.predict(x_test)

# %%
import xgboost as xgb
# Out:
# ---------------------------------------------------------------------------
# XGBoostLibraryNotFound                    Traceback (most recent call last)
# <ipython-input-12-5943d1bfe3f1> in <module>
# ----> 1 import xgboost as xgb
#
# ~\anaconda3\lib\site-packages\xgboost\__init__.py in <module>
#       7 import os
#       8
# ----> 9 from .core import DMatrix, DeviceQuantileDMatrix, Booster
#      10 from .training import train, cv
#      11 from . import rabit  # noqa
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in <module>
#     172
#     173 # load the XGBoost library globally
# --> 174 _LIB = _load_lib()
#     175
#     176
#
# ~\anaconda3\lib\site-packages\xgboost\core.py in _load_lib()
#     131 def _load_lib():
#     132     """Load xgboost Library."""
# --> 133     lib_paths = find_lib_path()
#     134     if not lib_paths:
#     135         return None
#
# ~\anaconda3\lib\site-packages\xgboost\libpath.py in find_lib_path()
# ...

# %%
import lightgbm as ltb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-7bb040ea221e> in <module>
# ----> 1 import lightgbm as ltb
#
# ~\anaconda3\lib\site-packages\lightgbm\__init__.py in <module>
#       6 import os
#       7
# ----> 8 from .basic import Booster, Dataset, register_logger
#       9 from .callback import early_stopping, print_evaluation, record_evaluation, reset_parameter
#      10 from .engine import CVBooster, cv, train
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in <module>
#      93
#      94
# ---> 95 _LIB = _load_lib()
#      96
#      97
#
# ~\anaconda3\lib\site-packages\lightgbm\basic.py in _load_lib()
#      84     if len(lib_path) == 0:
#      85         return None
# ---> 86     lib = ctypes.cdll.LoadLibrary(lib_path[0])
#      87     lib.LGBM_GetLastError.restype = ctypes.c_char_p
#      88     callback = ctypes.CFUNCTYPE(None, ctypes.c_char_p)
#
# ...
